# %%
import numpy as np
from Models import *
from Utilities import *
import matplotlib.pyplot as plt

# %%
bow = splitlist(readfile("Data\\BOW.txt"))
features_bow = bow[1]
labels_bow = bow[0]
features_bow = np.array(features_bow)
print("Number of samples BOW: ", len(features_bow))
print("Intial Shape of samples BOW: ", features_bow.shape)
features_bow, labels_bow= not_null(features_bow, labels_bow)
print("Shape of samples BOW after not null: ", features_bow.shape)
features_bow_scalled=  notglobalscale(features_bow)
# Out:
# Number of samples BOW:  20000
# Intial Shape of samples BOW:  (20000, 314)
# Shape of samples BOW after not null:  (19979, 314)

# %%
import umap.umap_ as umap
embeddings = umap.UMAP().fit(features_bow)
# Out:
# c:\Users\moham\OneDrive\Desktop\malware\env\lib\site-packages\sklearn\manifold\_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
l=20000
X_reduced = embeddings.transform(features_bow[:l])
print(X_reduced.shape)
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=labels_bow[:l], s=0.5);
# Out:
# (19979, 2)

# %%
features_mal = [y for x,y in enumerate(features_bow) if x%2 == 0]
features_mal = np.array(features_mal)
print(features_mal.shape, features_mal[0])
embeddingsmal = umap.UMAP().fit(features_mal)

# %%
l=9990
X_reduced_mal = embeddingsmal.transform(features_bow[:l])
print(X_reduced_mal.shape)
plt.scatter(X_reduced_mal[:, 0], X_reduced_mal[:, 1], s=0.5);
# Out:
# c:\Users\moham\OneDrive\Desktop\malware\env\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# (9990, 2)

# %%
features_mal = [y for x,y in enumerate(features_bow) if x%2 != 0]
features_mal = np.array(features_mal)
embeddingsmal = umap.UMAP().fit(features_mal)
X_reduced_mal = embeddingsmal.transform(features_bow[:l])
print(X_reduced_mal.shape)
plt.rcParams["figure.figsize"] = (7, 3)
plt.scatter(X_reduced_mal[:, 0], X_reduced_mal[:, 1], s=0.5);
# Out:
# c:\Users\moham\OneDrive\Desktop\malware\env\lib\site-packages\sklearn\manifold\_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\moham\OneDrive\Desktop\malware\env\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# (9990, 2)

# %%
plt.scatter(X_reduced_mal[:, 0], X_reduced_mal[:, 1], s=3);

# %%
features_bow_scalled=  notglobalscale(features_bow)
embeddings_scalled = umap.UMAP().fit(features_bow_scalled)

# %%
X_reduced_scalled = embeddings_scalled.transform(features_bow_scalled)
print(X_reduced_scalled.shape)
plt.rcParams["figure.figsize"] = (25, 25)
plt.scatter(X_reduced_scalled[:, 0], X_reduced_scalled[:, 1], c=labels_bow , s=5);
# Out:
# (19979, 2)

# %%
features_mal_scalled = [y for x,y in enumerate(features_bow_scalled) if x%2 == 0]
X_reduced_scalled_mal = embeddings_scalled.transform(features_mal_scalled)
print(X_reduced_scalled_mal.shape)
plt.rcParams["figure.figsize"] = (50, 50)
plt.scatter(X_reduced_scalled_mal[:, 0], X_reduced_scalled_mal[:, 1] , s=5);
# Out:
# c:\Users\moham\OneDrive\Desktop\malware\env\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# (9990, 2)

# %%
features_beg_scalled = [y for x,y in enumerate(features_bow_scalled) if x%2 != 0]
X_reduced_scalled_beg = embeddings_scalled.transform(features_beg_scalled)
print(X_reduced_scalled_beg.shape)
plt.rcParams["figure.figsize"] = (50, 50)
plt.scatter(X_reduced_scalled_beg[:, 0], X_reduced_scalled_beg[:, 1] , s=5);
# Out:
# (9989, 2)
